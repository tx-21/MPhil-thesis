# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7, lstm-2-sg7, lstm-3-sg7, lstm-4-sg7
fig, ax= plt.subplots(figsize=(6,4))
plt.suptitle('NH$_{3}$N forecasting with LSTM-sg7 with different input features')
means = np.array([0.0388,0.0379,0.0373,0.0369])
std = np.array  ([0.0003,0.0009,0.0002,0.0003])
mins = np.array ([0.0383,0.0366,0.0371,0.0365])
maxes = np.array([0.0391,0.0386,0.0377,0.0371])
ax.plot(means,c='black',linestyle='--',lw=1)
x=['Uni','Multi','Uni+pos','Multi+pos']
# create stacked errorbars:
ax.errorbar(np.arange(4), means, std, fmt='ok', lw=3)
ax.errorbar(np.arange(4), means, [means - mins, maxes - means],
             fmt='.k', ecolor='gray', lw=1)
ax.set_ylim(0.036,0.04)
ax.set_xlim(-0.3,3.3)
ax.margins(x=0.001)
ax.set_xticks(np.arange(0,4,1))
ax.set_xlabel('Model input feature')
ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(x)
# plt.savefig('nh3-forecasting-comparison.png',dpi=300,bbox_inches='tight')
# Out:
# [Text(0, 0, 'Uni'),
#  Text(1, 0, 'Multi'),
#  Text(2, 0, 'Uni+pos'),
#  Text(3, 0, 'Multi+pos')]

# %%
0.0388,0.0379,0.0373,0.0369
a = 100*round((0.0388-0.0379)/0.0388,3)
b = 100*round((0.0388-0.0373)/0.0388,3)
c = 100*round((0.0388-0.0369)/0.0388,3)
print(a,b,c)
# Out:
# 2.3 3.9 4.9

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(6,4))
plt.suptitle('Colour forecasting with LSTM-sg7 with different input features')
means = np.array([0.0161,0.0154,0.0143,0.0140])
std = np.array  ([0.0003,0.0007,0.0003,0.0003])
mins = np.array ([0.0158,0.0148,0.0138,0.0135])
maxes = np.array([0.0164,0.0164,0.0147,0.0143])
ax.plot(means,c='black',linestyle='--',lw=1)
x=['Uni','Multi','Uni+pos','Multi+pos']
# create stacked errorbars:
ax.errorbar(np.arange(4), means, std, fmt='ok', lw=3)
ax.errorbar(np.arange(4), means, [means - mins, maxes - means],
             fmt='.k', ecolor='gray', lw=1)
ax.set_ylim(0.013,0.017)
ax.set_xlim(-0.3,3.3)
ax.set_xticks(np.arange(0,4,1))
ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(x)
ax.set_xlabel('Number of input features')
# plt.savefig('colour-forecasting-comparison.png',dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Number of input features')

# %%
d = 100*round((0.0161-0.0154)/0.0388,3)
e = 100*round((0.0161-0.0143)/0.0388,3)
f = 100*round((0.0161-0.0140)/0.0388,3)

# %%
print(d,e,f)
# Out:
# 1.7999999999999998 4.6 5.4

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(6,4))
plt.suptitle('Comparison of the baseline model performance in forecasting NH$_{3}$N')
means = np.array([0.0319,0.0206,0.0189,0.0175])
std = np.array  ([0.0002,0.0002,0.0002,0.0001])
mins = np.array ([0.0317,0.0204,0.0187,0.0173])
maxes = np.array([0.0322,0.0208,0.0192,0.0176])
# ax.plot(means,c='black',linestyle='--',lw=1)
x=['DNN','RNN','GRU','LSTM']
# create stacked errorbars:
ax.bar(x, means, 0.3, yerr = std,color='#DEEBF7',edgecolor='black')
# ax.errorbar(np.arange(4), means, [means - mins, maxes - means],
#             fmt='.k', ecolor='gray', lw=1)
ax.set_ylim(0.015,0.035)
# ax.set_xlim(-0.3,3.6)
ax.set_xticks(np.arange(0,4,1))
ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(x)
ax.margins(x=0.1)
ax.set_xlabel('Machine learning models')
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\baseline-models-comparison-nh3.png',dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Machine learning models')

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(6,4))
plt.suptitle('Comparison of the baseline model performance in forecasting Colour')
means = np.array([0.0186,0.0160,0.0149,0.0148])
std = np.array  ([0.0002,0.0001,0.0003,0.0003])

# ax.plot(means,c='black',linestyle='--',lw=1)
x=['DNN','RNN','GRU','LSTM']
# create stacked errorbars:
ax.bar(x, means, 0.3, yerr = std, color='#0070C0',edgecolor='black')
# ax.errorbar(np.arange(4), means, [means - mins, maxes - means],
#             fmt='.k', ecolor='gray', lw=1)
ax.set_ylim(0.010,0.02)
# ax.set_xlim(-0.3,3.6)
ax.set_xticks(np.arange(0,4,1))
ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(x)
ax.margins(x=0.1)
ax.set_xlabel('Machine learning models')
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\baseline-models-comparison-colour.png',dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Machine learning models')

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")

fig, ax= plt.subplots(figsize=(6,4))
fig.suptitle('Effluent flow rate comparions of \nNENT landfill treatment plant and SHWEPP')
shw_eff = np.array([1991,2029,2120,2593,2552,2507])
nent_eff = np.array  ([85,84,85,87,86,85])


x=['1-4','1-5','1-6','1-7','1-8','1-9','1-10']
ax.bar(np.arange(6)-0.125, shw_eff, 0.25,color='#DEEBF7',edgecolor='black')
ax2 = ax.twinx()
ax2.bar(np.arange(6)+0.125, nent_eff, 0.25, color = '#0070C0',edgecolor='black')
ax2.set_ylim(40,100)
ax.set_ylim(1500,3500)
ax.set_ylabel('m$^{3}$/day')
ax2.set_ylabel('1000 m$^{3}$/day')
# ax.errorbar(np.arange(4), means, [means - mins, maxes - means],
#             fmt='.k', ecolor='gray', lw=1)
# ax.set_ylim(0.015,0.035)
# ax.set_xlim(-0.3,3.6)
# ax.set_xticks(np.arange(0,4,1))
# ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(x)
ax.margins(x=0.1)
ax.set_xlabel('Date')
plt.tight_layout()
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\flowrate-comparison.png',dpi=300,bbox_inches='tight')
# Out:
# <ipython-input-19-47e2475200a7>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(7,5))
plt.suptitle('Comparison of the model performances in forecasting NH$_{3}$N')
x = np.arange(7)
lstm_1 =     np.array([0.0405,0.0388,0.0388,0.0410,0.0392,0.0388,0.0395])
lstm_1_std = np.array([0.0004,0.0003,0.0003,0.0005,0.0006,0.0006,0.0010])
lstm_3 =     np.array([0.0426,0.0392,0.0373,0.0391,0.0403,0.0397,0.0400])
lstm_3_std = np.array([0.0005,0.0009,0.0002,0.0004,0.0008,0.0007,0.0001])

lstm_2 =     np.array([0.0411,0.0387,0.0379,0.0409,0.0389,0.0379,0.0380])
lstm_2_std = np.array([0.0007,0.0004,0.0009,0.0006,0.0004,0.0004,0.0003])
lstm_4 =     np.array([0.0432,0.0397,0.0369,0.0384,0.0404,0.0392,0.0399])
lstm_4_std = np.array([0.0009,0.0002,0.0003,0.0001,0.0007,0.0007,0.0007])

color4 = '#16558F'
color3 = '#0583D2'
color2 = '#61B0B7'
color1 = '#B8E3FF'

name=['','obs','sg-5','sg-7','sg-9','ew-2','ew-3','ew-4']
ax.bar(x - 0.3,lstm_1, 0.2, yerr = lstm_1_std,color=color1,edgecolor='black',label='LSTM-1')
ax2, ax3, ax4 = ax.twinx(),ax.twinx(),ax.twinx()

ax2.bar(x - 0.1,lstm_2, 0.2, yerr = lstm_2_std,color=color2,edgecolor='black',label='LSTM-2')
ax3.bar(x + 0.1,lstm_3, 0.2, yerr = lstm_3_std,color=color3,edgecolor='black',label='LSTM-3')
ax4.bar(x + 0.3,lstm_4, 0.2, yerr = lstm_4_std,color=color4,edgecolor='black',label='LSTM-4')

ax.legend(loc='upper right', bbox_to_anchor=(0.78, 1))
ax2.legend(loc='upper right', bbox_to_anchor=(0.78, 0.93))
ax3.legend(loc='upper right', bbox_to_anchor=(1, 1))
ax4.legend(loc='upper right', bbox_to_anchor=(1, 0.93))

y_low = 0.03
y_up = 0.046
ax.set_yticks(np.arange(y_low, y_up, .002))
ax.set_ylim( y_low,y_up)
ax2.set_ylim(y_low,y_up)
ax3.set_ylim(y_low,y_up)
ax4.set_ylim(y_low,y_up)
ax2.tick_params(axis='y', colors='white')
ax3.tick_params(axis='y', colors='white')
ax4.tick_params(axis='y', colors='white')

# ax.set_xticks(np.arange(0,8,1))
# ax.set_ylabel('Test loss (MSE)')
ax.grid(axis='y')
ax.set_xticklabels(name)
ax.set_ylabel('Test loss (MSE)')
# ax.margins(x=0.1)
ax.set_xlabel('Pre-processing methods')

plt.tight_layout()
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\comparison-nh3-models.png',dpi=300,bbox_inches='tight') 
plt.show()
# Out:
# <ipython-input-20-5fa74d8caae9>:55: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(name)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(7,5))
plt.suptitle('Comparison of the model performances in forecasting color')
x = np.arange(7)
lstm_1 =     np.array([0.0148,0.0168,0.0161,0.0143,0.0138,0.0138,0.0136])
lstm_1_std = np.array([0.0003,0.0005,0.0003,0.0005,0.0001,0.0001,0.0003])
lstm_3 =     np.array([0.0135,0.0144,0.0143,0.0120,0.0132,0.0134,0.0135])
lstm_3_std = np.array([0.0001,0.0002,0.0003,0.0007,0.0004,0.0004,0.0003])

lstm_2 =     np.array([0.0152,0.0159,0.0154,0.0146,0.0139,0.0135,0.0132])
lstm_2_std = np.array([0.0001,0.0006,0.0007,0.0001,0.0002,0.0002,0.0001])
lstm_4 =     np.array([0.0140,0.0155,0.0136,0.0129,0.0141,0.0136,0.0137])
lstm_4_std = np.array([0.0001,0.0003,0.0005,0.0007,0.0001,0.0005,0.0003])

color4 = '#16558F'
color3 = '#0583D2'
color2 = '#61B0B7'
color1 = '#B8E3FF'

name=['','obs','sg-5','sg-7','sg-9','ew-2','ew-3','ew-4']
ax.bar(x - 0.3,lstm_1, 0.2, yerr = lstm_1_std,color=color1,edgecolor='black',label='LSTM-1')
ax2, ax3, ax4 = ax.twinx(),ax.twinx(),ax.twinx()

ax2.bar(x - 0.1,lstm_2, 0.2, yerr = lstm_2_std,color=color2,edgecolor='black',label='LSTM-2')
ax3.bar(x + 0.1,lstm_3, 0.2, yerr = lstm_3_std,color=color3,edgecolor='black',label='LSTM-3')
ax4.bar(x + 0.3,lstm_4, 0.2, yerr = lstm_4_std,color=color4,edgecolor='black',label='LSTM-4')

ax.legend(loc='upper right', bbox_to_anchor=(0.78, 1))
ax2.legend(loc='upper right', bbox_to_anchor=(0.78, 0.93))
ax3.legend(loc='upper right', bbox_to_anchor=(1, 1))
ax4.legend(loc='upper right', bbox_to_anchor=(1, 0.93))

ax.set_ylim( 0.01,0.018)
ax2.set_ylim(0.01,0.018)
ax3.set_ylim(0.01,0.018)
ax4.set_ylim(0.01,0.018)
ax2.tick_params(axis='y', colors='white')
ax3.tick_params(axis='y', colors='white')
ax4.tick_params(axis='y', colors='white')

# ax.set_xticks(np.arange(0,8,1))
# ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(name)
# ax.margins(x=0.1)
ax.grid(axis='y')
ax.set_xlabel('Pre-processing methods')
ax.set_ylabel('Test loss (MSE)')
plt.tight_layout()
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\comparison-colour-models.png',dpi=300,bbox_inches='tight') 
plt.show()
# Out:
# <ipython-input-21-6e1b31c8099b>:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(name)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(7,5))
plt.suptitle('Comparison of testing and validation of NH$_{3}$-N forecasting models')
x = np.arange(7)
jan_lstm_1 =     np.array([0.0410,0.0405,0.0388,0.0388,0.0395,0.0392,0.0388])
jan_lstm_1_std = np.array([0.0005,0.0004,0.0003,0.0003,0.0010,0.0006,0.0006])
jan_lstm_3 =     np.array([0.0391,0.0426,0.0392,0.0373,0.0400,0.0403,0.0397])
jan_lstm_3_std = np.array([0.0004,0.0005,0.0009,0.0002,0.0001,0.0008,0.0007])

oct_lstm_1 =     np.array([0.0188,0.0175,0.0166,0.0180,0.0163,0.0161,0.0158])
oct_lstm_1_std = np.array([0.0002,0.0001,0.0001,0.0002,0.0003,0.0000,0.0004])
oct_lstm_3 =     np.array([0.0160,0.0164,0.0156,0.0155,0.0152,0.0150,0.0149])
oct_lstm_3_std = np.array([0.0005,0.0003,0.0001,0.0003,0.0002,0.0003,0.0001])

val =            np.array([1.3076,1.2366,1.2346,1.1804,1.1219,1.0969,1.0796])
val_std =        np.array([0.0214,0.0150,0.0520,0.0296,0.0079,0.0159,0.0112])


jan_lstm_1_p = []
oct_lstm_1_p = []
val_p = []

for i in range(len(jan_lstm_1)):
    jan_lstm_1_p.append((jan_lstm_1[i]/0.0410))
for i in range(len(oct_lstm_1)):
    oct_lstm_1_p.append((oct_lstm_1[i]/0.0188))
for i in range(len(val)):
    val_p.append((val[i]/1.3076))

color4 = '#16558F'
color3 = '#0583D2'
color2 = '#61B0B7'
color1 = '#B8E3FF'

name=['','sg-9','obs','sg-5','sg-7','ew-4','ew-2','ew-3']
ax.bar(x + 0.2,jan_lstm_1_p, 0.2,color=color1,edgecolor='black',label='Jan-LSTM-1')
ax2, ax3 = ax.twinx(),ax.twinx()

# ax2.bar(x - 0.3,jan_lstm_3, 0.2, yerr = jan_lstm_3_std,color=color2,edgecolor='black',label='Jan-LSTM-3')
ax2.bar(x - 0,oct_lstm_1_p, 0.2,color=color2,edgecolor='black',label='Oct-LSTM-1')
# ax4.bar(x + 0.1,oct_lstm_3, 0.2, yerr = oct_lstm_3_std,color=color4,edgecolor='black',label='Oct-LSTM-3')
ax3.bar(x - 0.2,val_p, 0.2,color=color3,edgecolor='black',label='Validation loss')

ax.legend(loc='upper right', bbox_to_anchor=(0.74, 1))
ax2.legend(loc='upper right', bbox_to_anchor=(0.74, 0.93))
ax3.legend(loc='upper right', bbox_to_anchor=(1, 1))

#ax.plot(jan_lstm_1_p)
#ax.plot(oct_lstm_1_p)
#ax.plot(val_p)
y_low = 0.8
y_up = 1.05
ax.set_yticks(np.arange(y_low, y_up, .02))
ax.set_ylabel('Test loss (MSE)')
ax.set_ylim(y_low,y_up)
ax2.set_ylim(y_low,y_up)
ax3.set_ylim(y_low,y_up)
#ax4.set_ylim(0.03,0.045)
ax2.tick_params(axis='y', colors='white')
ax3.tick_params(axis='y', colors='white')
# ax4.tick_params(axis='y', colors='white')
ax.grid(axis='y')
# ax.set_xticks(np.arange(0,8,1))
# ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(name)
# ax.margins(x=0.1)

plt.tight_layout()
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\comparison-nh3-models.png',dpi=300,bbox_inches='tight') 
plt.show()
# Out:
# <ipython-input-22-dca5fbb1912f>:73: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(name)

# %%
# attn

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.set_style("ticks")
# construct some data like what you have:
# lstm-sg7
fig, ax= plt.subplots(figsize=(7,5))
plt.suptitle('Comparison of the model performances in forecasting color')
x = np.arange(7)
lstm_1 =     np.array([0.0148,0.0168,0.0161,0.0143,0.0138,0.0138,0.0136])
lstm_1_std = np.array([0.0003,0.0005,0.0003,0.0005,0.0001,0.0001,0.0003])
lstm_3 =     np.array([0.0135,0.0144,0.0143,0.0120,0.0132,0.0134,0.0135])
lstm_3_std = np.array([0.0001,0.0002,0.0003,0.0007,0.0004,0.0004,0.0003])

lstm_2 =     np.array([0.0152,0.0159,0.0154,0.0146,0.0139,0.0135,0.0132])
lstm_2_std = np.array([0.0001,0.0006,0.0007,0.0001,0.0002,0.0002,0.0001])
lstm_4 =     np.array([0.0140,0.0155,0.0136,0.0129,0.0141,0.0136,0.0137])
lstm_4_std = np.array([0.0001,0.0003,0.0005,0.0007,0.0001,0.0005,0.0003])

lstm_attn =  np.array([0.0152,0.0141,0.0133,0.0138,0.0144,0.0146,0.0151])
lstm_attn_std = np.array([0.0002,0.0011,0.001,0.0004,0.0007,0.0003,0.0005])

lstm_1_49 = np.array([0.0139,0.014,0.0134,0.013,0.0129,0.0136,0.0126])
lstm_1_49_std = np.array([0.0004,0.0012,0.001,0.0005,0.0005,0.0004,0.0009])

color4 = '#16558F'
color3 = '#0583D2'
color2 = '#61B0B7'
color1 = '#B8E3FF'

name=['','obs','sg-5','sg-7','sg-9','ew-2','ew-3','ew-4']
ax.bar(x - 0.3,lstm_1, 0.2, yerr = lstm_1_std,color=color1,edgecolor='black',label='LSTM-1')
ax2, ax3, ax4 = ax.twinx(),ax.twinx(),ax.twinx()

ax2.bar(x - 0.1,lstm_2, 0.2, yerr = lstm_2_std,color=color2,edgecolor='black',label='LSTM-2')
ax3.bar(x + 0.1,lstm_3, 0.2, yerr = lstm_3_std,color=color3,edgecolor='black',label='LSTM-3')
ax4.bar(x + 0.3,lstm_1_49, 0.2, yerr = lstm_1_49_std,color=color4,edgecolor='black',label='LSTM-1-49')

ax.legend(loc='upper right', bbox_to_anchor=(0.78, 1))
ax2.legend(loc='upper right', bbox_to_anchor=(0.78, 0.93))
ax3.legend(loc='upper right', bbox_to_anchor=(1, 1))
ax4.legend(loc='upper right', bbox_to_anchor=(1, 0.93))

ax.set_ylim( 0.01,0.018)
ax2.set_ylim(0.01,0.018)
ax3.set_ylim(0.01,0.018)
ax4.set_ylim(0.01,0.018)
ax2.tick_params(axis='y', colors='white')
ax3.tick_params(axis='y', colors='white')
ax4.tick_params(axis='y', colors='white')

# ax.set_xticks(np.arange(0,8,1))
# ax.set_ylabel('Test loss (MSE)')
ax.set_xticklabels(name)
# ax.margins(x=0.1)
ax.grid(axis='y')
ax.set_xlabel('Pre-processing methods')
ax.set_ylabel('Test loss (MSE)')
plt.tight_layout()
# plt.savefig(r'D:\MPhil-thesis-github-library\MPhil-thesis\Presentation-notes\0511-seminar-pre\comparison-colour-models.png',dpi=300,bbox_inches='tight') 
plt.show()
# we are looking at trends like the decreaseing of test loss with more features are included in the models
# Out:
# C:\Users\Tim\AppData\Local\Temp/ipykernel_32584/3309924318.py:59: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(name)
